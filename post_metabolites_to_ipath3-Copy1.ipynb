# %%
# %pylab inline
import pandas as pd
import ipath
from IPython.display import SVG
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # map ids to ipath3

# %%
ids= ['C05499', 'C20359', 'C07207', 'C00022', 'C19712', 'C03564',
       'C15520', 'C05810', 'C05500', 'C14779', 'C00684', 'C15503',
       'C17339', 'C01401', 'C02939', 'C05455', 'C00736', 'C04734',
       'C10208', 'C05198', 'C02237', 'C12110', 'C00309', 'C00158',
       'C00855', 'C04916', 'C07577', 'C00310', 'C16649', 'C00184',
       'C00140', 'C02139', 'C14180', 'C00049', 'C09712', 'C02714',
       'C16618', 'C00123', 'C04785', 'C04020', 'C19585', 'C07394',
       'C05813', 'C00410', 'C05635', 'C02630', 'C14774', 'C03344',
       'C03943', 'C02763']

# %%
ipath.get_map('\n'.join(ids),keep_colors=True)

# %%
ipath.scale_map('map')
SVG(data='map_scaled.svg')

# %% [markdown]
# # From pandas to ipath3

# %%
D= pd.DataFrame(index=ids)
D['log2FC']=5*np.random.randn(D.shape[0])
D['p_values'] = 10.**(-np.random.randint(0,high=5,size=D.shape[0]))
D.head()
# Out:
#           log2FC  p_values
# C05499 -1.042565    0.0100
# C20359 -5.229462    0.0001
# C07207 -3.777300    0.1000
# C00022 -3.104458    1.0000
# C19712  2.780412    0.0010

# %%
selection= ipath.create_selection(D,color_column='log2FC',width_column='p_values')

# %%
print(selection[:300]+'...')
# Out:
# C05499 RGB(228,238,244) W0.49504950495049505
# C20359 RGB(110,174,210) W0.0
# C07207 RGB(160,204,226) W4.995499549954996
# C00022 RGB(179,214,232) W50.0
# C19712 RGB(250,202,177) W0.045004500450045004
# C03564 RGB(249,240,235) W50.0
# C15520 RGB(247,245,244) W0.045004500450045004
# C05810 RGB(245,246,247) W50.0
# C...

# %%
help(ipath.to_parameters)
# Out:
# Help on function to_parameters in module ipath:
#
# to_parameters(selection, export_type='svg', include_metabolic=True, include_secondary=False, include_antibiotic=False, include_microbial=False, whole_modules=False, whole_pathways=False, keep_colors=False, default_opacity=1, default_width=3, default_radius=7, default_color='#666666', query_reactions=False, tax_filter='', export_dpi=1200)

# %%
ipath.get_map(selection)

ipath.scale_map('map')
SVG(data='map_scaled.svg')
